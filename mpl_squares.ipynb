# %% [markdown]
# ## Plotting a simple line graph

# %%
import matplotlib.pyplot as plt
squares = [1, 4, 9, 16, 25]
plt.plot(squares)
plt.show()

# %% [markdown]
# ## Changing the Label Type and Graph Thickness

# %%
import matplotlib.pyplot as plt
squares= [1, 4, 9, 16, 25 ]
plt.plot(squares, linewidth=5)
# Set chart title and label axes.
plt.title("Square Numbers", fontsize=24)
plt.xlabel("Value", fontsize=14)
plt.ylabel("Square of Value", fontsize=14)
# Set size of tick labels.
plt.tick_params(axis='both', labelsize=14)
plt.show()

# %% [markdown]
# ## Correcting the Plot

# %%
import matplotlib.pyplot as plt
input_values = [1, 2, 3, 4, 5]
squares = [1, 4, 9, 16, 25]
plt.plot(input_values, squares, linewidth=5)
# Set chart title and label axes.
plt.title('Square Numbers')

# Set chart title
plt.title('Square Numbers')

# Label the axes
plt.xlabel('Value')
plt.ylabel('Square of Value')

# Show the plot
plt.show()

# %% [markdown]
# ## Plotting and Styling Individual Points with scatter()

# %%
import matplotlib.pyplot as plt
plt.scatter(2, 4, s=200)
# Set chart title and label axes.
plt.title("Square Numbers", fontsize=24)
plt.xlabel("Value", fontsize=14)
plt.ylabel("Square of Value", fontsize=14)
# Set size of tick labels.
plt.tick_params(axis='both', which='major', labelsize=14)
plt.show()

# %% [markdown]
# ## Plotting a Series of Points with scatter()

# %%
import matplotlib.pyplot as plt

# Data points
x_values = [1, 2, 3, 4, 5]
y_values = [1, 4, 9, 16, 25]

# Create a scatter plot
plt.scatter(x_values, y_values, s=100)

# Set chart title and label axes
plt.title('Square Numbers', fontsize=24)
plt.xlabel('Value', fontsize=14)
plt.ylabel('Square of Value', fontsize=14)

# Set size of tick labels
plt.tick_params(axis='both', which='major', labelsize=14)
# Display the plot
plt.show()

# %% [markdown]
# ## Calculating Data Automatically

# %%
import matplotlib.pyplot as plt

# Generate data
x_values = list(range(1, 1001))
y_values = [x**2 for x in x_values]

# Create a scatter plot
plt.scatter(x_values, y_values, s=40)

# Set chart title and label axes
plt.title('Square Numbers', fontsize=24)
plt.xlabel('Value', fontsize=14)
plt.ylabel('Square of Value', fontsize=14)

# Set the range for each axis
plt.axis([0, 1100, 0, 1100000])

# Display the plot
plt.show()

# %% [markdown]
# ## Removing Outlines from Data Points

# %%
import matplotlib.pyplot as plt

# Generate data
x_values = list(range(1, 1001))
y_values = [x**2 for x in x_values]

# Create a scatter plot without outlines
plt.scatter(x_values, y_values, s=40, edgecolor='none')

# Set chart title and label axes
plt.title('Square Numbers', fontsize=24)
plt.xlabel('Value', fontsize=14)
plt.ylabel('Square of Value', fontsize=14)

# Set the range for each axis
plt.axis([0, 1100, 0, 1100000])

# Display the plot
plt.show()

# %% [markdown]
# ## Defining Custom Colors

# %%
import matplotlib.pyplot as plt

# Sample data
x_values = [1, 2, 3, 4, 5]
y_values = [1, 4, 9, 16, 25]

# Create a scatter plot with a custom color
plt.scatter(x_values, y_values, s=100, color='red')

# Set chart title and label axes
plt.title('Custom Colors - Named Color', fontsize=24)
plt.xlabel('Value', fontsize=14)
plt.ylabel('Square of Value', fontsize=14)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
x_values = [1, 2, 3, 4, 5]
y_values = [1, 4, 9, 16, 25]

# Create a scatter plot with a custom color
plt.scatter(x_values, y_values, c=(0, 0, 0.8), edgecolor='none', s=40)

# Set chart title and label axes
plt.title('Custom Colors - Named Color', fontsize=24)
plt.xlabel('Value', fontsize=14)
plt.ylabel('Square of Value', fontsize=14)

# Display the plot
plt.show()
# Out:
# C:\Users\windo\AppData\Local\Temp\ipykernel_16716\427571873.py:8: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x_values, y_values, c=(0, 0, 0.8), edgecolor='none', s=40)

# %% [markdown]
# ## Using a Colormap

# %%
import matplotlib.pyplot as plt

# Generate data
x_values = list(range(1001))
y_values = [x**2 for x in x_values]

# Create a scatter plot with a colormap
plt.scatter(x_values, y_values, c=y_values, cmap=plt.cm.Blues, edgecolor='none', s=40)

# Set chart title and label axes
plt.title('Square Numbers', fontsize=24)
plt.xlabel('Value', fontsize=14)
plt.ylabel('Square of Value', fontsize=14)

# Set the range for each axis
plt.axis([0, 1100, 0, 1100000])
# Display the plot
plt.show()

# %% [markdown]
# ## Saving Your Plots Automatically

# %%
import matplotlib.pyplot as plt

# Generate data
x_values = list(range(1001))
y_values = [x**2 for x in x_values]

# Create a scatter plot
plt.scatter(x_values, y_values, c=y_values, cmap=plt.cm.Blues, edgecolor='none', s=40)

# Set chart title and label axes
plt.title('Square Numbers', fontsize=24)
plt.xlabel('Value', fontsize=14)
plt.ylabel('Square of Value', fontsize=14)

# Set the range for each axis
plt.axis([0, 1100, 0, 1100000])

# Adding grid for better readability
plt.grid(True)

# Save the plot
plt.savefig('square_numbers_plot.png', bbox_inches='tight')

# Display the plot
plt.show()

# %% [markdown]
# ## Trial Questions

# %% [markdown]
# 1. Cubes: A number raised to the third power is a cube Plot the first five
# cubic numbers, and then plot the first 5000 cubic numbers

# %%
import matplotlib.pyplot as plt
cubes= [1, 8, 27, 64, 125]
plt.plot(cubes)
plt.show()

# %% [markdown]
# ## To plot the first 5000 cubic numbers

# %%
import matplotlib.pyplot as plt

# Data for the first 5000 cubic numbers
x_values = list(range(1, 5001))
y_values = [x**3 for x in x_values]

# Create a scatter plot for the first 5000 cubic numbers
plt.scatter(x_values, y_values, c='blue', s=1)

# Set chart title and label axes
plt.title('First 5000 Cubic Numbers', fontsize=24)
plt.xlabel('Value', fontsize=14)
plt.ylabel('Cube of Value', fontsize=14)

# Display the plot
plt.show()

# %% [markdown]
# ## To apply a colormap to your cubes plot

# %%
import matplotlib.pyplot as plt

# Generate data
x_values = list(range(1, 5001))
y_values = [x**3 for x in x_values]

# Create a scatter plot with a colormap
plt.scatter(x_values, y_values, c=y_values, cmap=plt.cm.viridis, edgecolor='none', s=10)

# Set chart title and label axes
plt.title('First 5000 Cubic Numbers with Colormap', fontsize=24)
plt.xlabel('Value', fontsize=14)
plt.ylabel('Cube of Value', fontsize=14)

# Add a color bar
plt.colorbar()

# Display the plot
plt.show()

# %% [markdown]
# ## Creating the RandomWalk() Class

# %%
from random import choice
class RandomWalk():
   """class to generate random walks."""
   def __init__(self, num_points=5000):
     """Initialize attributes of a walk."""
     self.num_points = num_points
    # All walks start at (0, 0).
     self.x_values = [0]
     self.y_values = [0]

# %% [markdown]
# ## Choosing Directions

# %%
def fill_walk(self):
        """Calculate all the points in the walk."""

        # Keep taking steps until the walk reaches the desired length
        while len(self.x_values) < self.num_points:
            # Decide which direction to go and how far to go in that direction
            x_direction = choice([1, -1])
            x_distance = choice(range(0, 5))
            x_step = x_direction * x_distance

            y_direction = choice([1, -1])
            y_distance = choice(range(0, 5))
            y_step = y_direction * y_distance

            # Reject moves that go nowhere
            if x_step == 0 and y_step == 0:
                continue

            # Calculate the new position
            x = self.x_values[-1] + x_step
            y = self.y_values[-1] + y_step

            self.x_values.append(x)
            self.y_values.append(y)

# %% [markdown]
# ## Plotting the Random Walk

# %%
from random import choice
class RandomWalk:
  """A class to generate random walks."""
  def __init__(self, num_points=5000):
    """Initialize attributes of a walk."""
    self.num_points = num_points
    # All walks start at (0, 0).
    self.x_values = [0]
    self.y_values = [0]

  def fill_walk(self):
    """Calculate all the points in the walk."""
    # Keep taking steps until the walk reaches the desired length.
    while len(self.x_values) < self.num_points:
      # Decide which direction to go, and how far to go.
      x_direction = choice([1, -1])
      x_distance = choice([0, 1, 2, 3, 4])
      x_step = x_direction * x_distance
      y_direction = choice([1, -1])
      y_distance = choice([0, 1, 2, 3, 4])
      y_step = y_direction * y_distance
      # Reject moves that go nowhere.
      if x_step == 0 and y_step == 0:
        continue
        # Calculate the new position.
      x = self.x_values[-1] + x_step
      y = self.y_values[-1] + y_step
      self.x_values.append(x)
      self.y_values.append(y)

# %%
import matplotlib.pyplot as plt
# Make a random walk.

rw = RandomWalk()
rw.fill_walk()
# Plot the points in the walk.
plt.style.use('classic')
fig, ax = plt.subplots()
ax.scatter(rw.x_values, rw.y_values, s=15)
ax.set_aspect('equal')
plt.show()

# %% [markdown]
# ## Generating Multiple Random Walks

# %%
from random import choice
class RandomWalk:
  """A class to generate random walks."""
  def __init__(self, num_points=5000):
    """Initialize attributes of a walk."""
    self.num_points = num_points
    # All walks start at (0, 0).
    self.x_values = [0]
    self.y_values = [0]

  def fill_walk(self):
    """Calculate all the points in the walk."""
    # Keep taking steps until the walk reaches the desired length.
    while len(self.x_values) < self.num_points:
      # Decide which direction to go, and how far to go.
      x_direction = choice([1, -1])
      x_distance = choice([0, 1, 2, 3, 4])
      x_step = x_direction * x_distance
      y_direction = choice([1, -1])
      y_distance = choice([0, 1, 2, 3, 4])
      y_step = y_direction * y_distance
      # Reject moves that go nowhere.
      if x_step == 0 and y_step == 0:
        continue
        # Calculate the new position.
      x = self.x_values[-1] + x_step
      y = self.y_values[-1] + y_step
      self.x_values.append(x)
      self.y_values.append(y)

# %%
import matplotlib.pyplot as plt

# Make a random walk, and plot the points.
rw = RandomWalk()
rw.fill_walk()
plt.scatter(rw.x_values, rw.y_values, s=15)
plt.show()
# Ask if the user wants to make another walk
keep_running = input("Make another walk? (y/n): ")
if keep_running.lower() == 'n':
        'break'

# %% [markdown]
# ## Coloring the Points

# %%
from random import choice
class RandomWalk:
  """A class to generate random walks."""
  def __init__(self, num_points=5000):
    """Initialize attributes of a walk."""
    self.num_points = num_points
    # All walks start at (0, 0).
    self.x_values = [0]
    self.y_values = [0]

  def fill_walk(self):
    """Calculate all the points in the walk."""
    # Keep taking steps until the walk reaches the desired length.
    while len(self.x_values) < self.num_points:
      # Decide which direction to go, and how far to go.
      x_direction = choice([1, -1])
      x_distance = choice([0, 1, 2, 3, 4])
      x_step = x_direction * x_distance
      y_direction = choice([1, -1])
      y_distance = choice([0, 1, 2, 3, 4])
      y_step = y_direction * y_distance
      # Reject moves that go nowhere.
      if x_step == 0 and y_step == 0:
        continue
        # Calculate the new position.
      x = self.x_values[-1] + x_step
      y = self.y_values[-1] + y_step
      self.x_values.append(x)
      self.y_values.append(y)

# %%
import matplotlib.pyplot as plt
    # Make a random walk, and plot the points.
rw = RandomWalk()
rw.fill_walk()
    
point_numbers = list(range(rw.num_points))  # Fixed the typo here
plt.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Blues,
                edgecolor='none', s=15)
plt.show()

# %% [markdown]
# ## Plotting the Starting and Ending Points

# %%
import matplotlib.pyplot as plt
    # Make a random walk, and plot the points.
rw = RandomWalk(num_points=5000)
rw.fill_walk()

    # Plot the points
plt.figure(figsize=(10, 6))
plt.scatter(rw.x_values, rw.y_values, c=rw.x_values, cmap=plt.cm.Blues, edgecolor='none', s=15)

    # Emphasize the first and last points
plt.scatter(0, 0, c='green', edgecolor='none', s=100)  # Starting point in green
plt.scatter(rw.x_values[-1], rw.y_values[-1], c='red', edgecolor='none', s=100)
    
    # Display the plot
plt.show()

    # Ask if the user wants to make another walk
keep_running = input("Make another walk? (y/n): ")
if keep_running.lower() == 'n':
        'break'

# %% [markdown]
# ## Cleaning Up the Axes

# %%
import matplotlib.pyplot as plt
    # Make a random walk, and plot the points.
rw = RandomWalk(num_points=5000)
rw.fill_walk()
    
    # Plot the points
plt.figure(figsize=(10, 6))
plt.scatter(rw.x_values, rw.y_values, c=rw.x_values, cmap=plt.cm.Blues, edgecolor='none', s=15)

    # Emphasize the first and last points
plt.scatter(0, 0, c='green', edgecolor='none', s=100)  # Starting point in green
plt.scatter(rw.x_values[-1], rw.y_values[-1], c='red', edgecolor='none', s=100)  # Ending point in red

    # Remove the axes
plt.gca().axes.get_xaxis().set_visible(False)
plt.gca().axes.get_yaxis().set_visible(False)
    
    # Display the plot
plt.show()

    # Ask if the user wants to make another walk
keep_running = input("Make another walk? (y/n): ")
if keep_running.lower() == 'n':
        'break'
